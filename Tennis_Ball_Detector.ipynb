# %%
# !pip install roboflow
# !pip install ultralytics
# Out:
# ^C
#   WARNING: The script filetype.exe is installed in 'C:\Users\Smoke Nandos\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script roboflow.exe is installed in 'C:\Users\Smoke Nandos\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# streamlit 1.37.1 requires pillow<11,>=7.1.0, but you have pillow 12.2.0 which is incompatible.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting roboflow
#   Downloading roboflow-1.3.7-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: certifi in c:\programdata\anaconda3\lib\site-packages (from roboflow) (2025.1.31)
# Requirement already satisfied: idna==3.7 in c:\programdata\anaconda3\lib\site-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in c:\programdata\anaconda3\lib\site-packages (from roboflow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\programdata\anaconda3\lib\site-packages (from roboflow) (1.4.4)
# Requirement already satisfied: matplotlib in c:\programdata\anaconda3\lib\site-packages (from roboflow) (3.9.2)
# Requirement already satisfied: numpy>=1.18.5 in c:\programdata\anaconda3\lib\site-packages (from roboflow) (1.26.4)
# Collecting opencv-python-headless==4.10.0.84 (from roboflow)
#   Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: Pillow>=7.1.2 in c:\programdata\anaconda3\lib\site-packages (from roboflow) (10.4.0)
# Collecting pi-heif<2 (from roboflow)
#   Downloading pi_heif-1.3.0-cp312-cp312-win_amd64.whl.metadata (6.5 kB)
# Collecting pillow-avif-plugin<2 (from roboflow)
#   Downloading pillow_avif_plugin-1.5.5-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in c:\programdata\anaconda3\lib\site-packages (from roboflow) (0.21.0)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in c:\programdata\anaconda3\lib\site-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in c:\programdata\anaconda3\lib\site-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in c:\programdata\anaconda3\lib\site-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\programdata\anaconda3\lib\site-packages (from roboflow) (6.0.1)
# Requirement already satisfied: requests_toolbelt in c:\programdata\anaconda3\lib\site-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typer>=0.12.0 in c:\users\smoke nandos\appdata\roaming\python\python312\site-packages (from roboflow) (0.24.1)
# Collecting Pillow>=7.1.2 (from roboflow)
#   Downloading pillow-12.2.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: colorama in c:\programdata\anaconda3\lib\site-packages (from tqdm>=4.41.0->roboflow) (0.4.6)
# Requirement already satisfied: click>=8.2.1 in c:\users\smoke nandos\appdata\roaming\python\python312\site-packages (from typer>=0.12.0->roboflow) (8.3.2)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\smoke nandos\appdata\roaming\python\python312\site-packages (from typer>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in c:\programdata\anaconda3\lib\site-packages (from typer>=0.12.0->roboflow) (13.7.1)
# Requirement already satisfied: annotated-doc>=0.0.2 in c:\users\smoke nandos\appdata\roaming\python\python312\site-packages (from typer>=0.12.0->roboflow) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->roboflow) (1.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->roboflow) (4.51.0)
# Requirement already satisfied: packaging>=20.0 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\programdata\anaconda3\lib\site-packages (from matplotlib->roboflow) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests->roboflow) (3.3.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.12.0->roboflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\programdata\anaconda3\lib\site-packages (from rich>=12.3.0->typer>=0.12.0->roboflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\programdata\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.12.0->roboflow) (0.1.0)
# Downloading roboflow-1.3.7-py3-none-any.whl (195 kB)
# Downloading opencv_python_headless-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#    -- ------------------------------------- 2.6/38.8 MB 12.5 MB/s eta 0:00:03
#    ----- ---------------------------------- 5.8/38.8 MB 14.1 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.7/38.8 MB 15.5 MB/s eta 0:00:02
#    ------------- -------------------------- 13.4/38.8 MB 16.1 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.3/38.8 MB 16.5 MB/s eta 0:00:02
#    --------------------- ------------------ 21.2/38.8 MB 16.8 MB/s eta 0:00:02
#    ------------------------- -------------- 24.9/38.8 MB 17.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.6/38.8 MB 17.3 MB/s eta 0:00:01
#    --------------------------------- ------ 32.5/38.8 MB 17.3 MB/s eta 0:00:01
#    ------------------------------------- -- 36.2/38.8 MB 17.3 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 17.1 MB/s eta 0:00:00
# Downloading pi_heif-1.3.0-cp312-cp312-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 15.5 MB/s eta 0:00:00
# Downloading pillow-12.2.0-cp312-cp312-win_amd64.whl (7.1 MB)
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ----------------- ---------------------- 3.1/7.1 MB 15.4 MB/s eta 0:00:01
#    -------------------------------------- - 6.8/7.1 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 7.1/7.1 MB 16.2 MB/s eta 0:00:00
# Downloading pillow_avif_plugin-1.5.5-cp312-cp312-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    --------------- ------------------------ 3.9/9.9 MB 18.1 MB/s eta 0:00:01
#    ---------------------------- ----------- 7.1/9.9 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 16.2 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Installing collected packages: pillow-avif-plugin, filetype, Pillow, opencv-python-headless, pi-heif, roboflow
# Successfully installed Pillow-12.2.0 filetype-1.2.0 opencv-python-headless-4.10.0.84 pi-heif-1.3.0 pillow-avif-plugin-1.5.5 roboflow-1.3.7

# %% [markdown]
# ### Get Dataset

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="AWDwtg9pD24XRGUtpE3C")
project = rf.workspace("viren-dhanwani").project("tennis-ball-detection")
version = project.version(6)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in tennis-ball-detection-6 to yolov5pytorch:: 100%|██████████| 52040/52040 [00:03<00:00, 14437.89it/s]
# Extracting Dataset Version Zip to tennis-ball-detection-6 in yolov5pytorch:: 100%|██████████| 1168/1168 [00:00<00:00, 1452.17it/s]

# %%
import shutil

# %%
shutil.move("tennis-ball-detection-6/train",
            "tennis-ball-detection-6/tennis-ball-detection-6/train",
            )

shutil.move("tennis-ball-detection-6/test",
            "tennis-ball-detection-6/tennis-ball-detection-6/test",
            )

shutil.move("tennis-ball-detection-6/valid",
            "tennis-ball-detection-6/tennis-ball-detection-6/valid",
            )
# Out:
# 'tennis-ball-detection-6/tennis-ball-detection-6/valid'

# %%
# !yolo task = detect mode = train model = yolov516u.pt data = (dataset.location)/data.yaml epochs = 150 imgsz = 650
